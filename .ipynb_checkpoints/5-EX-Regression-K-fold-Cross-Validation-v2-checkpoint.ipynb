# %% [markdown]
# Creative Commons CC BY 4.0 Lynd Bacon & Associates, Ltd. Not warranted to be suitable for any particular purpose. (You're on your own!)

# %% [markdown]
# # K-Fold Cross-Validation for Regression
#
# In the following we're going to apply the _K-fold cross-validation_ method to assess model performance on data that the model "hasn't seen."

# %% [markdown]
# ## Preliminaries
#
# Let's first do some set-ups, and get some packages we're going to need.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn import linear_model  # OLS 
from sklearn.metrics import mean_squared_error, r2_score, SCORERS # Basic metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate, cross_val_predict

# %% [markdown]
# # Data Input and Preprocessing
#
# Let's get the patient satisfaction data in the file `DECART-patSat.csv` into a Pandas DataFrame, and then extract into a numpy array the data we want to use.

# %%
ptSatDF=pd.read_csv('../DATA/ML/DECART-patSat.csv')
ptSatDF.columns
# Out:
# Index(['caseID', 'patSat', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9',
#        'ptCat'],
#       dtype='object')

# %% [markdown]
# That `ptCat` variable is categorical:

# %%
ptSatDF.ptCat.value_counts()
# Out:
# 1    679
# 0    596
# 2    536
# Name: ptCat, dtype: int64

# %% [markdown]
# ## Dummy Coding, or "OneHot" Coding
#
# To use `ptCat` in a regression model we need to code it somehow.  Let's "dummy" (zero/one) code it, omitting the first category:

# %%
ptSatDF[['ptCat1','ptCat2']]=pd.get_dummies(ptSatDF.ptCat,drop_first=True)
ptSatDF2=ptSatDF.drop(['ptCat','caseID'],axis=1)
ptSatDF2.columns
# Out:
# Index(['patSat', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9', 'ptCat1',
#        'ptCat2'],
#       dtype='object')

# %%
## get_dummies가 어떻게 역할을 하는지에 대한 cell
pd.DataFrame(ptSatDF.ptCat).tail()
ptSatDF[['ptCat1','ptCat2']].tail()
# Out:
#       ptCat
# 1806      0
# 1807      0
# 1808      1
# 1809      0
# 1810      2
#       ptCat1  ptCat2
# 1806       0       0
# 1807       0       0
# 1808       1       0
# 1809       0       0
# 1810       0       1

# %% [markdown]
# ## Effects Coding of Categorical Predictor Variables Digression

# %% [markdown]
# If we wanted _effects_ coding of `ptCat` instead of dummy coding, we could just dummy code first, omitting the reference category, and then replace every pair of zeros with a pair of -1's.
#
# See if the following works to do this for you, or if it produces unexpected results.

# %%
ptCat=ptSatDF.ptCat.to_numpy()   # select the ptCat col
pcEC=pd.get_dummies(ptCat,drop_first=True)
rowTot=pcEC.apply(sum,axis=1)  # calc row totals
a=-1
pcEC.loc[rowTot==0]=a
pcEC.drop_duplicates()
# Out:
#      1    2
# 0  255  255
# 1    0    1
# 3    1    0

# %% [markdown]
# ## Creating numpy Arrays for CV Training and Testing

# %% [markdown]
# Let's now make the numpy objects we're going to feed into our regression model.

# %%
ptSatX=ptSatDF2.iloc[:,1:].to_numpy()  # predictor vars
ptSatY=ptSatDF2.iloc[:,0].to_numpy()   # pt satisfaction dep var
ptSatX.shape  # Just checking
ptSatY.shape
ptSatY.min()
# Out:
# (1811, 10)
# (1811,)
# 1

# %% [markdown]
#  # A Simple Way To Do K Fold Cross-Validation
#
# Here we do 10 fold CV, retaining fit and timing metrics

# %%
np.random.seed(57)

# %% [markdown]
# ### Available Metrics
#
# These are for a variety of "learner" model types.

# %%
# Here's what the available metrics are. Uncomment and exec to list them.
sorted(SCORERS.keys())
# Out:
# ['accuracy',
#  'adjusted_mutual_info_score',
#  'adjusted_rand_score',
#  'average_precision',
#  'balanced_accuracy',
#  'brier_score_loss',
#  'completeness_score',
#  'explained_variance',
#  'f1',
#  'f1_macro',
#  'f1_micro',
#  'f1_samples',
#  'f1_weighted',
#  'fowlkes_mallows_score',
#  'homogeneity_score',
#  'mutual_info_score',
#  'neg_log_loss',
#  'neg_mean_absolute_error',
#  'neg_mean_squared_error',
#  'neg_mean_squared_log_error',
#  'neg_median_absolute_error',
#  'normalized_mutual_info_score',
#  'precision',
#  'precision_macro',
#  'precision_micro',
#  'precision_samples',
#  'precision_weighted',
#  'r2',
#  'recall',
#  'recall_macro',
#  'recall_micro',
#  'recall_samples',
#  'recall_weighted',
#  'roc_auc',
#  'v_measure_score']

# %%
regr=linear_model.LinearRegression()  # lin reg model w/ defaults
scoring=['r2','neg_mean_squared_error','explained_variance'] # list of metrics to be returned
scores = cross_validate(regr, ptSatX, ptSatY, cv=10,
                               scoring=scoring,
                       return_train_score=True)

# %% [markdown]
# `scores` should be a python dict.  We can make it easier to inspect by making a DataFrame using it.

# %%
type(scores)
#scores.keys()
#scores.values()
pd.DataFrame(scores)
# Out:
# dict
#    fit_time  score_time   test_r2  train_r2  test_neg_mean_squared_error  \
# 0  0.003590    0.002813  0.744029  0.701565                    -1.811215
# 1  0.002463    0.002906  0.692256  0.707983                    -2.206559
# 2  0.002552    0.002917  0.731350  0.704014                    -1.600421
# 3  0.002398    0.002879  0.643689  0.712851                    -2.194789
# 4  0.002397    0.002944  0.683885  0.708667                    -2.001926
# 5  0.002404    0.002833  0.668084  0.710313                    -2.085132
# 6  0.002423    0.002850  0.715595  0.705548                    -1.710859
# 7  0.002400    0.002854  0.687332  0.708571                    -2.324607
# 8  0.002408    0.003205  0.680903  0.708593                    -1.912441
# 9  0.002436    0.002861  0.742841  0.702754                    -1.600901
#
#    train_neg_mean_squared_error  test_explained_variance  \
# 0                     -1.919569                 0.744030
# 1                     -1.876766                 0.692308
# 2                     -1.941993                 0.731660
# 3                     -1.877032                 0.649401
# 4                     -1.898538                 0.684635
# 5                     -1.888684                 0.672082
# 6                     -1.928804                 0.716347
# 7                     -1.862466                 0.687441
# 8                     -1.907681                 0.680906
# 9                     -1.940552                 0.743057
#
#    train_explained_variance
# 0                  0.701565
# 1                  0.707983
# 2                  0.704014
# 3                  0.712851
# 4                  0.708667
# 5                  0.710313
# 6                  0.705548
# 7                  0.708571
# 8                  0.708593
# 9                  0.702754

# %% [markdown]
# Summarizing the folds' statistics:

# %%
pd.DataFrame(scores).describe()
# Out:
#         fit_time  score_time    test_r2   train_r2  \
# count  10.000000   10.000000  10.000000  10.000000
# mean    0.002696    0.003149   0.698996   0.707086
# std     0.000625    0.000824   0.033374   0.003535
# min     0.002105    0.001846   0.643689   0.701565
# 25%     0.002430    0.002889   0.681648   0.704397
# 50%     0.002451    0.002908   0.689794   0.708277
# 75%     0.002475    0.003065   0.727411   0.708648
# max     0.003871    0.004591   0.744029   0.712851
#
#        test_neg_mean_squared_error  train_neg_mean_squared_error  \
# count                    10.000000                     10.000000
# mean                     -1.944885                     -1.904209
# std                       0.260065                      0.028104
# min                      -2.324607                     -1.941993
# 25%                      -2.167375                     -1.926495
# 50%                      -1.957183                     -1.903110
# 75%                      -1.735948                     -1.879945
# max                      -1.600421                     -1.862466
#
#        test_explained_variance  train_explained_variance
# count                10.000000                 10.000000
# mean                  0.700187                  0.707086
# std                   0.032005                  0.003535
# min                   0.649401                  0.701565
# 25%                   0.681838                  0.704397
# 50%                   0.689874                  0.708277
# 75%                   0.727831                  0.708648
# max                   0.744030                  0.712851

# %% [markdown]
# # Predictions From Cross-Validated Model
#
# Predicted values for the dependent measure based on the _test_ cv folds can be obtained for Dx purposes.

# %%
# Predicted patient satisfaction ratings

# regrCVpreds will be a 1D array of predicted values based on test data
 
regrCVPreds=cross_val_predict(regr,ptSatX,ptSatY,cv=10,n_jobs=-1)

# %% [markdown]
# ### Plot of Predicted Based on Test Folds vs. Actual
#
# Note the semicolon at the end of the last line.  Remove it and run the following cell again to see what it does.

# %%
# points=plt.scatter(ptSatY,regrCVPreds,alpha=0.1)
plt.figure(figsize=(8,8))
plot=sns.regplot(ptSatY,regrCVPreds,
                 scatter=True,
                 color='.1',x_jitter=.2,
                 scatter_kws={"alpha":0.4,"color":"grey"})

plt.xlim(0.5,10.5)

plot=plot.set(xlabel='PT Sat Rating',ylabel='Predicted Rating');

# %% [markdown]
# # Another Way to Do the Kfold Shuffle
#
# Let's use the `radon` data and try cross-validation in a slightly different way.

# %%
radon=pd.read_csv('../DATA/ML/radon.csv')

# %% [markdown]
# ## Data Munging
#
# We've seen that there is a row of data that's missing a value for the `hhincome` variable.  Let's kick that observation to the curb, and work with the rest of the data.
#
# The following stmt selects all rows that aren't missing a value for `hhincome`, gets columns `lcanmort` through `hhincome`, and drops columns `radon`.

# %%
radon2=radon.loc[radon.hhincome.notnull(),'lcanmort':'hhincome'] \
        .drop('radon',axis=1)
radon2.shape
radon2.columns
# Out:
# (2880, 7)
# Index(['lcanmort', 'lnradon', 'obesity', 'over65', 'cursmoke', 'evrsmoke',
#        'hhincome'],
#       dtype='object')

# %% [markdown]
# ## 20 Fold CV
#
# Next will set up to do 20 fold cross-validation, pre-shuffling the data, and setting the random seed to a constant so that results can be replicated if need be.

# %%
kf=KFold(n_splits=20,random_state=99,shuffle=True)
X=radon2.iloc[:,1:].to_numpy()
y=radon2.loc[:,'lcanmort'].to_numpy()

cvres=list()  # This will hold cv results # []도 가능

regr=linear_model.LinearRegression() # define a reg model to use

for traindx, testdx in kf.split(X):  # loop over folds
    #result를 넣을 dictionary 정의
    resDict={}                       # Dictionary to hold fold results

    # Fold별 Train, Test; x, y 나누기
    XTrain=X[traindx]                
    yTrain=y[traindx]
    XTest=X[testdx]
    yTest=y[testdx]

    # Regression model fit 정의 (위에서 정의한 regr를 사용한다.)
    regModel=regr.fit(XTrain,yTrain)
    
    # XTrain에 따른 prediction 값, MSE, R2을 도출한다. 
    trainPred=regModel.predict(XTrain)
    trainR2=r2_score(yTrain,trainPred)
    trainMSE=mean_squared_error(yTrain,trainPred)
    
    # XTest에 따른 prediction 값, MSE, R2을 도출한다.     
    testPred=regModel.predict(XTest)
    testR2=r2_score(yTest,testPred)
    testMSE=mean_squared_error(yTest,testPred)
    
    # result 값들을 resDict에 넣는다. (.update라는 함수를 사용)
    resDict.update({'trainR2':trainR2,
                    'testR2':testR2,
                    'trainMSE':trainMSE,
                    'testMSE':testMSE})
    
    # cvres라는 list에 나온 resultDictionary를 모두 모은다. 
    cvres.append(resDict)

# %%
# Rearranging cols to make train vs test comparisons easier
cvresDF=pd.DataFrame(cvres)[['trainMSE','testMSE','trainR2','testR2']]

# %% [markdown]
# ## Inspecting Results
#
# Let's summarize results.

# %%
cvresDF
cvresDF.describe()
# Out:
#       trainMSE     testMSE   trainR2    testR2
# 0   165.913376  175.103015  0.465619  0.467835
# 1   167.118174  152.291621  0.464053  0.495716
# 2   164.126013  209.219646  0.472399  0.342312
# 3   167.027701  154.482423  0.460220  0.544366
# 4   167.125752  152.638416  0.461812  0.531502
# 5   166.501674  164.245754  0.464057  0.494852
# 6   167.654218  141.874075  0.466295  0.454407
# 7   166.119500  171.737683  0.465306  0.472689
# 8   168.463209  126.813798  0.465221  0.466951
# 9   162.079522  247.957006  0.470901  0.391290
# 10  165.778723  177.908827  0.471656  0.333667
# 11  164.691352  198.250392  0.467215  0.439069
# 12  166.688970  160.484882  0.467251  0.434074
# 13  165.066794  191.135356  0.465881  0.463534
# 14  167.712144  141.115713  0.459364  0.577696
# 15  167.187731  151.013835  0.466261  0.447222
# 16  167.989391  135.454280  0.462163  0.529832
# 17  165.643259  180.459483  0.465089  0.474862
# 18  166.449514  164.815178  0.467961  0.420424
# 19  167.432242  146.562284  0.468899  0.383829
#          trainMSE     testMSE    trainR2     testR2
# count   20.000000   20.000000  20.000000  20.000000
# mean   166.338463  167.178183   0.465881   0.458306
# std      1.504895   28.563857   0.003490   0.063702
# min    162.079522  126.813798   0.459364   0.333667
# 25%    165.744857  149.900947   0.464056   0.430661
# 50%    166.595322  162.365318   0.465750   0.465242
# 75%    167.248859  178.546491   0.467429   0.495068
# max    168.463209  247.957006   0.472399   0.577696

# %% [markdown]
# Compare train and test metrics directly by looking at the differences betwen the within fold metrics.

# %%
cvresDF['TestTrainMSEDiff']=cvresDF.testMSE-cvresDF.trainMSE  # This is test-train
cvresDF['TrainTestR2Diff']=cvresDF.trainR2-cvresDF.testR2     # This is train-test

# %%
cvresDF[['TestTrainMSEDiff','TrainTestR2Diff']].describe()
# Out:
#        TestTrainMSEDiff  TrainTestR2Diff
# count         20.000000        20.000000
# mean           0.839720         0.007575
# std           30.068707         0.067153
# min          -41.649411        -0.118332
# 25%          -17.347912        -0.031012
# 50%           -4.230004         0.000309
# 75%           12.801634         0.036768
# max           85.877483         0.137989

# %% [markdown]
# # UDU:  Repeat the K Fold Procedure, Above, Using the pt Sat Data

# %% [markdown]
# ## Read datafile ("patient satisfaction")

# %%
patSAT = pd.read_csv('../DATA/ML/DECART-patSat.csv')
patSAT.columns
patSAT.tail()
patSAT.describe().round(2)
# Out:
# Index(['caseID', 'patSat', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9',
#        'ptCat'],
#       dtype='object')
#       caseID  patSat  q2  q3  q4  q5  q6  q7  q8  q9  ptCat
# 1806    1806       5   4   8   4   9   9   7   9   9      0
# 1807    1807       2   5   3   3   3   6   7   8   8      0
# 1808    1808       6   6   6   7   7   7   7   7   7      1
# 1809    1809       1   1   1  10   1   5   1   9  10      0
# 1810    1810      10  10  10  10  10  10  10  10  10      2
#         caseID   patSat       q2       q3       q4       q5       q6       q7  \
# count  1811.00  1811.00  1811.00  1811.00  1811.00  1811.00  1811.00  1811.00
# mean    905.00     6.07     5.88     6.27     6.14     6.06     7.25     7.46
# std     522.93     2.55     2.65     2.66     2.62     2.55     2.42     2.28
# min       0.00     1.00     1.00     1.00     1.00     1.00     1.00     1.00
# 25%     452.50     5.00     4.00     5.00     5.00     5.00     5.00     6.00
# 50%     905.00     6.00     6.00     7.00     6.00     6.00     8.00     8.00
# 75%    1357.50     8.00     8.00     8.00     8.00     8.00     9.00     9.00
# max    1810.00    10.00    10.00    10.00    10.00    10.00    10.00    10.00
#
#             q8       q9    ptCat
# count  1811.00  1811.00  1811.00
# mean      7.89     7.77     0.97
# std       2.14     2.21     0.79
# min       1.00     1.00     0.00
# 25%       7.00     7.00     0.00
# 50%       8.00     8.00     1.00
# 75%      10.00    10.00     2.00
# max      10.00    10.00     2.00

# %%
y = patSAT.iloc[:,1].to_numpy()
X = patSAT.iloc[:,2:-1].to_numpy()

# %%
kf=KFold(n_splits=10,random_state=99,shuffle=True)

cvres=list()  # This will hold cv results # []도 가능

regr=LinearRegression() # define a reg model to use

for traindx, testdx in kf.split(X):  # loop over folds
    #result를 넣을 dictionary 정의
    resDict={}                       # Dictionary to hold fold results

    # Fold별 Train, Test; x, y 나누기
    XTrain=X[traindx]                
    yTrain=y[traindx]
    XTest=X[testdx]
    yTest=y[testdx]

    # Regression model fit 정의 (위에서 정의한 regr를 사용한다.)
    regModel=regr.fit(XTrain,yTrain)
    
    # XTrain에 따른 prediction 값, MSE, R2을 도출한다. 
    trainPred=regModel.predict(XTrain)
    trainR2=r2_score(yTrain,trainPred)
    trainMSE=mean_squared_error(yTrain,trainPred)
    
    # XTest에 따른 prediction 값, MSE, R2을 도출한다.     
    testPred=regModel.predict(XTest)
    testR2=r2_score(yTest,testPred)
    testMSE=mean_squared_error(yTest,testPred)
    
    # model 도출
    slip, inter = np.polyfit(yTrain,trainPred,deg=1)

    # result 값들을 resDict에 넣는다. (.update라는 함수를 사용)
    resDict.update({'slip':slip,
                    'inter':inter,
                    'trainR2':trainR2,
                    'testR2':testR2,
                    'trainMSE':trainMSE,
                    'testMSE':testMSE})
    
    # cvres라는 list에 나온 resultDictionary를 모두 모은다. 
    cvres.append(resDict)

cvresDF=pd.DataFrame(cvres)[['slip', 'inter','trainMSE','testMSE','trainR2','testR2']]
cvresDF
cvresDF.describe()
# Out:
#        slip     inter  trainMSE   testMSE   trainR2    testR2
# 0  0.687331  1.886380  2.046114  2.075699  0.687331  0.655334
# 1  0.676606  1.966750  2.095939  1.615250  0.676606  0.757592
# 2  0.679723  1.941508  2.073105  1.827195  0.679723  0.729582
# 3  0.688334  1.890644  2.007441  2.421057  0.688334  0.656360
# 4  0.687153  1.898194  2.017685  2.342137  0.687153  0.663936
# 5  0.689750  1.885480  2.037419  2.145812  0.689750  0.636269
# 6  0.685418  1.907756  2.067409  1.867669  0.685418  0.681614
# 7  0.686095  1.915781  2.063429  1.909457  0.686095  0.666807
# 8  0.681350  1.918936  2.070090  1.857943  0.681350  0.708341
# 9  0.692497  1.871238  1.971629  2.761118  0.692497  0.620531
#             slip      inter   trainMSE    testMSE    trainR2     testR2
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.685426   1.908267   2.045026   2.082334   0.685426   0.677637
# std     0.004844   0.028824   0.037200   0.342642   0.004844   0.042527
# min     0.676606   1.871238   1.971629   1.615250   0.676606   0.620531
# 25%     0.682367   1.887446   2.022618   1.860374   0.682367   0.655590
# 50%     0.686624   1.902975   2.054771   1.992578   0.686624   0.665371
# 75%     0.688084   1.918147   2.069420   2.293055   0.688084   0.701659
# max     0.692497   1.966750   2.095939   2.761118   0.692497   0.757592
