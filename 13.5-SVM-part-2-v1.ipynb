# %% [markdown]
# Creative Commons CC BY 4.0 Lynd Bacon & Associates, Ltd. Not warranted to be suitable for any particular purpose. (You're on your own!)

# %% [markdown]
# #  More Support Vector Classification: Grid Searching
#
# Here we'll try grid searching to find good parameter settings.

# %% [markdown]
# # Get Packages

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython.display import display, Markdown
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import scikitplot as skplt
from sklearn import linear_model  
from sklearn.model_selection import cross_val_predict, cross_validate
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
from sklearn.metrics import roc_curve, precision_score, recall_score
from sklearn.svm import LinearSVC
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import os
import shelve
# %matplotlib inline

# %% [markdown]
# # Get Data and Munge It

# %%
cervical=pd.read_csv('../DATA/ML/risk_factors_cervical_cancer.csv',na_values='?')

# %%
cervicalFeats=cervical.loc[:,'Age':'Hormonal Contraceptives (years)'].copy()

# %%
cervical2=pd.concat([cervical.Biopsy,cervicalFeats],axis=1).dropna(axis=0)

# %%
X=cervical2.iloc[:,1:].to_numpy()  # features
y=cervical2.Biopsy.to_numpy()
X.shape
y.shape
# Out:
# (676, 9)
# (676,)

# %% [markdown]
# # Set Up Train/Test Split, Pipeline, Grid Search Parameters

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
            random_state=99,stratify=y)

# %%
pipe = Pipeline([("scaler", preprocessing.StandardScaler()), 
                 ("polynom",PolynomialFeatures()),
                 ("svm", LinearSVC(max_iter=100000,random_state=99))])

# %%
param_grid={"polynom__degree":[1,2],
           "svm__C":[0.001,0.01,0.1,1.0]}

# %%
grid = GridSearchCV(pipe, param_grid=param_grid, cv=10,
                       return_train_score=True,iid=False)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('polynom', PolynomialFeatures(degree=2, include_bias=True, interaction_only=False)), ('svm', LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=100000,
#      multi_class='ovr', penalty='l2', random_state=99, tol=0.0001,
#      verbose=0))]),
#        fit_params=None, iid=False, n_jobs=None,
#        param_grid={'polynom__degree': [1, 2], 'svm__C': [0.001, 0.01, 0.1, 1.0]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Best params:
# {'polynom__degree': 1, 'svm__C': 0.001}
#
# Best cross-validation score: 0.93
# Test-set score: 0.93

# %% [markdown]
# # Multiple Learners in a Grid Search
#
# Here we try training both logistic regression and a support vector classifier as part of our grid search.

# %%
pipe = Pipeline([('preprocessing', StandardScaler()), ('classifier', LinearSVC())])

# %%
param_grid = [
    {'classifier': [LinearSVC(max_iter=1000000,random_state=99)],
     'preprocessing': [StandardScaler(), MinMaxScaler(), None],
     'classifier__C': [0.001, 0.01, 0.1, 1]},
    {'classifier': [linear_model.LogisticRegression(max_iter=1000000,
                            solver='lbfgs',random_state=99)],
     'preprocessing': [StandardScaler(), MinMaxScaler(), None],
     'classifier__C': [0.001, 0.01, 0.1, 1]}
    ]

# %%
grid = GridSearchCV(pipe, param_grid=param_grid, cv=10,
                   return_train_score=True,iid=False)

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('preprocessing', StandardScaler(copy=True, with_mean=True, with_std=True)), ('classifier', LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))]),
#        fit_params=None, iid=False, n_jobs=None,
#        param_grid=[{'classifier': [LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000000,
#      multi_class='ovr', penalty='l2', random_state=99, tol=0.0001,
#      verbose=0)], 'preprocessing': [StandardScaler(copy=True, with_mea...rue), MinMaxScaler(copy=True, feature_range=(0, 1)), None], 'classifier__C': [0.001, 0.01, 0.1, 1]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Best params:
# {'classifier': LinearSVC(C=0.001, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000000,
#      multi_class='ovr', penalty='l2', random_state=99, tol=0.0001,
#      verbose=0), 'classifier__C': 0.001, 'preprocessing': StandardScaler(copy=True, with_mean=True, with_std=True)}
#
# Best cross-validation score: 0.93
# Test-set score: 0.93

# %%
cvresDF=pd.DataFrame(grid.cv_results_)
cvresDF
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002646      0.000280         0.000690        0.000065
# 1        0.002851      0.000390         0.000886        0.000140
# 2        0.007557      0.000866         0.000813        0.000045
# 3        0.004921      0.000589         0.000955        0.000178
# 4        0.002006      0.000063         0.000648        0.000023
# 5        0.064351      0.012594         0.000652        0.000099
# 6        0.011545      0.002099         0.000657        0.000026
# 7        0.002144      0.000049         0.000642        0.000022
# 8        0.755320      0.113329         0.000793        0.000126
# 9        0.120757      0.027962         0.000713        0.000081
# 10       0.005057      0.000608         0.000655        0.000019
# 11       8.697331      1.391335         0.000911        0.000194
# 12       0.007259      0.000538         0.000635        0.000012
# 13       0.006642      0.000213         0.000617        0.000005
# 14       0.012185      0.000462         0.000498        0.000007
# 15       0.006201      0.000342         0.000627        0.000008
# 16       0.005559      0.000022         0.000636        0.000048
# 17       0.021760      0.004190         0.000521        0.000031
# 18       0.006987      0.000292         0.000642        0.000016
# 19       0.006657      0.000695         0.000738        0.000214
# 20       0.040268      0.007862         0.000519        0.000040
# 21       0.008718      0.000876         0.000609        0.000019
# 22       0.008818      0.000520         0.000596        0.000026
# 23       0.046789      0.007521         0.000494        0.000019
#
#                                      param_classifier param_classifier__C  \
# 0   LinearSVC(C=0.001, class_weight=None, dual=Tru...               0.001
# 1   LinearSVC(C=0.001, class_weight=None, dual=Tru...               0.001
# 2   LinearSVC(C=0.001, class_weight=None, dual=Tru...               0.001
# 3   LinearSVC(C=0.001, class_weight=None, dual=Tru...                0.01
# 4   LinearSVC(C=0.001, class_weight=None, dual=Tru...                0.01
# 5   LinearSVC(C=0.001, class_weight=None, dual=Tru...                0.01
# 6   LinearSVC(C=0.001, class_weight=None, dual=Tru...                 0.1
# 7   LinearSVC(C=0.001, class_weight=None, dual=Tru...                 0.1
# 8   LinearSVC(C=0.001, class_weight=None, dual=Tru...                 0.1
# 9   LinearSVC(C=0.001, class_weight=None, dual=Tru...                   1
# 10  LinearSVC(C=0.001, class_weight=None, dual=Tru...                   1
# 11  LinearSVC(C=0.001, class_weight=None, dual=Tru...                   1
# 12  LogisticRegression(C=1, class_weight=None, dua...               0.001
# 13  LogisticRegression(C=1, class_weight=None, dua...               0.001
# 14  LogisticRegression(C=1, class_weight=None, dua...               0.001
# 15  LogisticRegression(C=1, class_weight=None, dua...                0.01
# 16  LogisticRegression(C=1, class_weight=None, dua...                0.01
# 17  LogisticRegression(C=1, class_weight=None, dua...                0.01
# 18  LogisticRegression(C=1, class_weight=None, dua...                 0.1
# 19  LogisticRegression(C=1, class_weight=None, dua...                 0.1
# 20  LogisticRegression(C=1, class_weight=None, dua...                 0.1
# 21  LogisticRegression(C=1, class_weight=None, dua...                   1
# 22  LogisticRegression(C=1, class_weight=None, dua...                   1
# 23  LogisticRegression(C=1, class_weight=None, dua...                   1
#
#                                   param_preprocessing  \
# 0   StandardScaler(copy=True, with_mean=True, with...
# 1       MinMaxScaler(copy=True, feature_range=(0, 1))
# 2                                                None
# 3   StandardScaler(copy=True, with_mean=True, with...
# 4       MinMaxScaler(copy=True, feature_range=(0, 1))
# 5                                                None
# 6   StandardScaler(copy=True, with_mean=True, with...
# 7       MinMaxScaler(copy=True, feature_range=(0, 1))
# 8                                                None
# 9   StandardScaler(copy=True, with_mean=True, with...
# 10      MinMaxScaler(copy=True, feature_range=(0, 1))
# 11                                               None
# 12  StandardScaler(copy=True, with_mean=True, with...
# 13      MinMaxScaler(copy=True, feature_range=(0, 1))
# 14                                               None
# 15  StandardScaler(copy=True, with_mean=True, with...
# 16      MinMaxScaler(copy=True, feature_range=(0, 1))
# 17                                               None
# 18  StandardScaler(copy=True, with_mean=True, with...
# 19      MinMaxScaler(copy=True, feature_range=(0, 1))
# 20                                               None
# 21  StandardScaler(copy=True, with_mean=True, with...
# 22      MinMaxScaler(copy=True, feature_range=(0, 1))
# 23                                               None
#
#                                                params  split0_test_score  \
# 0   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 1   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 2   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 3   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 4   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 5   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 6   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 7   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 8   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 9   {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 10  {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 11  {'classifier': LinearSVC(C=0.001, class_weight...           0.923077
# 12  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 13  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 14  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 15  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 16  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 17  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 18  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 19  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 20  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 21  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 22  {'classifier': LogisticRegression(C=1, class_w...           0.923077
# 23  {'classifier': LogisticRegression(C=1, class_w...           0.923077
#
#     split1_test_score  ...  split2_train_score  split3_train_score  \
# 0            0.923077  ...            0.934066            0.934211
# 1            0.923077  ...            0.934066            0.934211
# 2            0.923077  ...            0.934066            0.934211
# 3            0.923077  ...            0.934066            0.934211
# 4            0.923077  ...            0.934066            0.934211
# 5            0.923077  ...            0.934066            0.934211
# 6            0.923077  ...            0.934066            0.934211
# 7            0.923077  ...            0.934066            0.934211
# 8            0.923077  ...            0.934066            0.934211
# 9            0.923077  ...            0.934066            0.934211
# 10           0.923077  ...            0.934066            0.934211
# 11           0.923077  ...            0.934066            0.934211
# 12           0.923077  ...            0.934066            0.934211
# 13           0.923077  ...            0.934066            0.934211
# 14           0.923077  ...            0.934066            0.934211
#
# [24 rows x 33 columns]

# %%
pd.DataFrame(cvresDF.iloc[cvresDF.mean_test_score.idxmax(),])
# Out:
#                                                                      0
# mean_fit_time                                               0.00264649
# std_fit_time                                               0.000279545
# mean_score_time                                            0.000689602
# std_score_time                                             6.47631e-05
# param_classifier     LinearSVC(C=0.001, class_weight=None, dual=Tru...
# param_classifier__C                                              0.001
# param_preprocessing  StandardScaler(copy=True, with_mean=True, with...
# params               {'classifier': LinearSVC(C=0.001, class_weight...
# split0_test_score                                             0.923077
# split1_test_score                                             0.923077
# split2_test_score                                             0.923077
# split3_test_score                                             0.921569
# split4_test_score                                                 0.94
# split5_test_score                                                 0.94
# split6_test_score                                                 0.94
# split7_test_score                                                 0.94
# split8_test_score                                                 0.94
# split9_test_score                                                 0.94
# mean_test_score                                                0.93308
# std_test_score                                              0.00848537
# rank_test_score                                                      1
# split0_train_score                                            0.934066
# split1_train_score                                            0.934066
# split2_train_score                                            0.934066
# split3_train_score                                            0.934211
# split4_train_score                                            0.932166
# split5_train_score                                            0.932166
# split6_train_score                                            0.932166
# split7_train_score                                            0.932166
# split8_train_score                                            0.932166
# split9_train_score                                            0.932166
# mean_train_score                                              0.932941
# std_train_score                                            0.000949161

# %% [markdown]
# ## Apply multiple models include SVC in the BreastCA data

# %%
from sklearn import datasets
breastCA=datasets.load_breast_cancer()
target_values, value_counts = np.unique(breastCA['target'], return_counts=True)
X=breastCA['data']  # features
y=breastCA['target'] # labels: 0=malignancy, 1=benign
y=1-y                # relabelled: 0=benign, 1=malignancy

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
            random_state=99,stratify=y)

# %%
pipe = Pipeline([('preprocessing', StandardScaler()), ('classifier', LinearSVC())])

# %%
param_grid = [
    {'classifier': [LinearSVC(max_iter=1000000,random_state=99)],
     'preprocessing': [StandardScaler(), MinMaxScaler(), None],
     'classifier__C': [0.001, 0.01, 0.1, 1]},
    {'classifier': [linear_model.LogisticRegression(max_iter=1000000,
                            solver='lbfgs',random_state=99)],
     'preprocessing': [StandardScaler(), MinMaxScaler(), None],
     'classifier__C': [0.001, 0.01, 0.1, 1]}
    ]

# %%
grid = GridSearchCV(pipe, param_grid=param_grid, cv=10,
                   return_train_score=True,iid=False)

# %%
grid.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('preprocessing', StandardScaler(copy=True, with_mean=True, with_std=True)), ('classifier', LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))]),
#        fit_params=None, iid=False, n_jobs=None,
#        param_grid=[{'classifier': [LinearSVC(C=0.01, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000000,
#      multi_class='ovr', penalty='l2', random_state=99, tol=0.0001,
#      verbose=0)], 'preprocessing': [StandardScaler(copy=True, with_mean...rue), MinMaxScaler(copy=True, feature_range=(0, 1)), None], 'classifier__C': [0.001, 0.01, 0.1, 1]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
print("Best params:\n{}\n".format(grid.best_params_))
print("Best cross-validation score: {:.2f}".format(grid.best_score_))
print("Test-set score: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# Best params:
# {'classifier': LinearSVC(C=0.01, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000000,
#      multi_class='ovr', penalty='l2', random_state=99, tol=0.0001,
#      verbose=0), 'classifier__C': 0.01, 'preprocessing': StandardScaler(copy=True, with_mean=True, with_std=True)}
#
# Best cross-validation score: 0.98
# Test-set score: 0.97
